# %% [markdown]
# <a href="https://colab.research.google.com/github/atamurodovanodira/Fuzzy/blob/main/Fuzzy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy

# %%
pip install matplotlib

# %%
pip install scikit-fuzzy

# %%
pip install scikit-image

# %%
pip install fuzzywuzzy

# %%
from skimage.filters import threshold_otsu
import matplotlib.pyplot as plt
from skimage import data

# %%
image = data.camera()

# %%
threshold_value = threshold_otsu(image)
binary_image = image > threshold_value

# %%
fig, axes = plt.subplots(ncols=2, figsize=(8, 3))
ax = axes.ravel()
ax[0] = plt.subplot(1, 2, 1)
ax[1] = plt.subplot(1, 2, 2)

ax[0].imshow(image, cmap=plt.cm.gray)
ax[0].set_title('Original Image')
ax[0].axis('off')

ax[1].imshow(binary_image, cmap=plt.cm.gray)
ax[1].set_title('Thresholded Image')
ax[1].axis('off')

plt.show()
